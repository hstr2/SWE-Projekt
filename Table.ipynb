// %%
#r "nuget:XPlot.Plotly,3.0.1"

// %%
using X.Plot.Plotly;
using System;
using System.Data;
using System.Data.OleDb;
using System.XML;
using System.Text;

class Table
{
    public void XMLread(string[] args)
    {
        XMLDocument XMLdoc = new XMLDocument();
        XMLdoc.Load("results.XML");
        foreach(XmlNode xmlnode in XMLdoc.DocumentElement.Childnodes[0].Childnodes)
            int calc.student5 = Console.ReadLine(xmlnode.Attribution["calc.student5"].value)
            int calc.student10 = Console.ReadLine(xmlnode.Attribution["calc.student10"].value)
            int calc.student15 = Console.ReadLine(xmlnode.Attribution["calc.student15"].value)
            int calc.student20 = Console.ReadLine(xmlnode.Attribution["calc.student20"].value)
            int calc.teacher5 = Console.ReadLine(xmlnode.Attribution["calc.teacher5"].value)
            int calc.teacher10 = Console.ReadLine(xmlnode.Attribution["calc.teacher10"].value)
            int calc.teacher15 = Console.ReadLine(xmlnode.Attribution["calc.teacher15"].value)
            int calc.teacher20 = Console.ReadLine(xmlnode.Attribution["calc.teacher20"].value)
            int calc.teachersneeded5 = Console.ReadLine(xmlnode.Attribution["calc.teachersneeded5"].value)
            int calc.teachersneeded10 = Console.ReadLine(xmlnode.Attribution["calc.teachersneeded10"].value)
            int calc.teachersneeded15 = Console.ReadLine(xmlnode.Attribution["calc.teachersneeded15"].value)
            int calc.teachersneeded20 = Console.ReadLine(xmlnode.Attribution["calc.teachersneeded20"].value)
            int calc.schools5 = Console.ReadLine(xmlnode.Attribution["calc.schools5"].value)
            int calc.schools10 = Console.ReadLine(xmlnode.Attribution["calc.schools10"].value)
            int calc.schools15 = Console.ReadLine(xmlnode.Attribution["calc.schools15"].value)
            int calc.schools20 = Console.ReadLine(xmlnode.Attribution["calc.schools20"].value)
            int calc.schoolsneeded5 = Console.ReadLine(xmlnode.Attribution["calc.schoolsneeded5"].value)
            int calc.schoolsneeded10 = Console.ReadLine(xmlnode.Attribution["calc.schoolsneeded10"].value)
            int calc.schoolsneeded15 = Console.ReadLine(xmlnode.Attribution["calc.schoolsneeded15"].value)
            int calc.schoolsneeded20 = Console.ReadLine(xmlnode.Attribution["calc.schoolsneeded20"].value)
            
    }
        
    public void ADONET_dynTabelle1(Calculation calc)
    {
        
    DataTable Table = new DataTable();
    //Spalten erzeugen
    Table.Columns.Add("year", System.Type.GetType("System.Int32"));
    Table.Columns.Add("students", System.Type.GetType("System.Int32"));
    Table.Columns.Add("teacher", System.Type.GetType("System.Int32"));
    Table.Columns.Add("needed teacher", System.Type.GetType("System.Int32"));
    Table.Columns.Add("schools", System.Type.GetType("System.Int32"));
    Table.Columns.Add("needed schools", System.Type.GetType("System.Int32"));

    //1. Zeile erzeugen
    DataRow row1 = Table.NewRow();
    //Wert fehlt
    row1 ["year"] = +5;
    row1 ["students"] = calc.students5;
    row1 ["teacher"] = calc.teachers5;
    row1 ["needed teacher"] = calc.teachersneeded5;
    row1 ["schools"] = calc.schools;
    row1 ["needed schools"] = calc.schoolsneeded5;
    //Anfügen an Tabelle
    Table.Rows.Add(row1);
    //weitere sind identisch
    //2.Zeile
    DataRow row2 = Table.NewRow();
    //Wert fehlt
    row2 ["year"] = +10;
    row2 ["students"] = calc.students10;
    row2 ["teacher"] = calc.teachers10;
    row2 ["needed teacher"] = calc.teachersneeded10;
    row2 ["schools"] = calc.schools;
    row2 ["needed schools"] = calc.schoolsneeded10;
    //Anfügen an Tabelle
    Table.Rows.Add(row2);
    //3.Zeile
    DataRow row3 = Table.NewRow();
    //Wert fehlt
    row3 ["year"] = +15;
    row3 ["students"] = calc.students15;
    row3 ["teacher"] = calc.teachers15;
    row3 ["needed teacher"] = calc.teachersneeded15;
    row3 ["schools"] = calc.schools;
    row3 ["needed schools"] = calc.schoolsneeded15;
    //Anfügen an Tabelle
    Table.Rows.Add(row3);
    //4.Zeile
    DataRow row4 = Table.NewRow();
    //Wert fehlt
    row4 ["year"] = +20;
    row4 ["students"] = calc.students20;
    row4 ["teacher"] = calc.teachers20;
    row4 ["needed teacher"] = calc.teachersneeded20;
    row4 ["schools"] = calc.schools;
    row4 ["needed schools"] = calc.schoolsneeded20;
    //Anfügen an Tabelle
    Table.Rows.Add(row4);
    }
}
